# %% [markdown]
# # Polynomial Regression
#
# Polynomial regression is simply linear regression but first the predictors are transformed. The formula for simple polynomial regression becomes:
#
# $$y=\theta_0  + \theta_1 x+\theta_2 x^2+...+\theta_d x^d+\epsilon$$
#
# Here we implement it below:

# %%
# to make this notebook's output stable across runs
import numpy as np
np.random.seed(42)

# %%
X = 2 * np.random.rand(100,1)
y = 4 + 4 * X + 2 * X**2 + np.random.randn(100,1)

# %%
# %matplotlib inline
import matplotlib as mpl
import matplotlib.pyplot as plt

plt.plot(X, y, "b.")
plt.xlabel("$x$", fontsize=18)
plt.ylabel("$y$", rotation=0, fontsize=18)
#plt.axis([0, 2, 0, 15])
plt.show()

# %%
new_X = np.hstack((X, X**2))

# %%
from sklearn.linear_model import LinearRegression

poly_reg = LinearRegression()
poly_reg.fit(new_X,y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
test_data_x = np.linspace(0,2,100)
transformed_x = np.vstack((test_data_x, test_data_x**2))
test_data_y = poly_reg.predict(transformed_x.T)

# %%
plt.plot(test_data_x, test_data_y, color="r")
plt.plot(test_data_x, 4+4*test_data_x+2*test_data_x**2, color="g")
plt.plot(X, y, "b.")
plt.xlabel("$x$", fontsize=18)
plt.ylabel("$y$", rotation=0, fontsize=18)
plt.show()

# %%
print(poly_reg.intercept_)
print(poly_reg.coef_)
# Out:
# [4.56140272]
# [[2.63887939 2.5810637 ]]

# %% [markdown]
# Our model above is the red line while the green line is the actual polynomial. We can see our model is very close! Polynomial regression methods can also be used for classification in a logistic setting where the log odds now become polynomials
